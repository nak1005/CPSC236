# %% [markdown]
# # Selections and Loops

# %% [markdown]
# ## 3.1 Letter Grade Converter
# Create a program that converts number grades to letter grades.
#
# ### Console:
# ```powershell
# Letter Grade Converter
#
# Enter numerical grade: 90
# Letter grade: A
#
# Continue? (y/n): y
#
# Enter numerical grade: 88
# Letter grade: A
#
# Continue? (y/n): y
#
# Enter numerical grade: 80
# Letter grade: B
#
# Continue? (y/n): y
#
# Enter numerical grade: 67
# Letter grade: C
#
# Continue? (y/n): y
#
# Enter numerical grade: 59
# Letter grade: F
#
# Continue? (y/n): n
#
# Bye!
# ```
#
# ### Specifications:
# - Assume that the user will enter valid integers for the grades.
# - The program should continue only if the user enters “y” or “Y” to continue.
# - The grading criteria is as follows:
#
# | Letter |	Range |
# |---|-------|
# | A |	88-100 |
# | B |	80-87 |
# | C |	67-79 |
# | D |	60-66 |
# | F |	<60 |

# %%
print("Letter Grade Converter\n")
cont='y'
while cont =='y' or cont =='Y':
    grade=int(input("Enter numerical grade: "))
    if grade>100:
        letter="Not Valid"
    elif grade>=88:
        letter='A'
    elif grade>=80:
        letter='B'
    elif grade>=67:
        letter='C'
    elif grade>=60:
        letter='D'
    else:
        letter='F'
    print("Letter Grade: ", letter)
    cont=input("\nContinue? (y/n): ")
print("\nBye!")
# Out:
# Letter Grade Converter
#
# Enter numerical grade: 100
# Letter Grade:  A
#
# Continue? (y/n): y
# Enter numerical grade: 88
# Letter Grade:  A
#
# Continue? (y/n): Y
# Enter numerical grade: 87
# Letter Grade:  B
#
# Continue? (y/n): y
# Enter numerical grade: 80
# Letter Grade:  B
#
# Continue? (y/n): Y
# Enter numerical grade: 79
# Letter Grade:  C
#
# Continue? (y/n): y
# Enter numerical grade: 67
# Letter Grade:  C
#
# Continue? (y/n): Y
# Enter numerical grade: 66
# Letter Grade:  D
#
# Continue? (y/n): y
# Enter numerical grade: 60
# Letter Grade:  D
#
# Continue? (y/n): y
# Enter numerical grade: 59
# Letter Grade:  F
#
# Continue? (y/n): Y
# Enter numerical grade: 101
# Letter Grade:  Not Valid
#
# Continue? (y/n): n
#
# Bye!

# %% [markdown]
# ## 3.2 - Tip Calculator
# Create a program that calculates three options for an appropriate tip to leave after a meal at a restaurant.
#
# ### Console
# ```powershell
# Tip Calculator
#
# Cost of meal: 52.31
#
# 15%
# Tip amount:	7.85
# Total amount: 60.16
#
# 20%
# Tip amount:	10.46
# Total amount: 62.77
#
# 25%
# Tip amount:	13.08
# Total amount: 65.39
# ```
#
# ### Specifications:
# - The program should calculate and display the cost of tipping at 15%, 20%, or 25%.
# - Assume the user will enter valid data.
# - The program should round results to a maximum of two decimal places.

# %%
print("Tip Calculator")

cost=float(input("Cost of meal:" ))

tip1=round(cost*0.15, 2)
tip2=round(cost*0.2, 2)
tip3=round(cost*0.25, 2)

print("\n15%\nTip amount: ", tip1, "\nTotal amount: ", round(tip1+cost, 2))
print("\n20%\nTip amount: ", tip2, "\nTotal amount: ", round(tip2+cost, 2))
print("\n25%\nTip amount: ", tip3, "\nTotal amount: ", round(tip3+cost, 2))
# Out:
# Tip Calculator
# Cost of meal:52.31
#
# 15%
# Tip amount:  7.85
# Total amount:  60.16
#
# 20%
# Tip amount:  10.46
# Total amount:  62.77
#
# 25%
# Tip amount:  13.08
# Total amount:  65.39

# %% [markdown]
# ## 3.3 - Change Calculator
# Create a program that calculates the coins needed to make change for the specified number of cents.
#
# ### Console
# ```powershell
# Change Calculator
#
# Enter number of cents (0-99): 99
#
# Quarters: 3
# Dimes:	2
# Nickels: 0
# Pennies: 4
#
# Continue? (y/n): y
#
# Enter number of cents (0-99): 55
#
# Quarters: 2
# Dimes:	0
# Nickels: 1
# Pennies: 0
#
# Continue? (y/n): n
#
# Bye!
# ```
#
# ### Specifications
# - The program should display the minimum number of quarters, dimes, nickels, and pennies that one needs to make up the specified number of cents.
# - Assume that the user will enter a valid integer for the number of cents.
# - The program should continue only if the user enters “y” or “Y” to continue.

# %%
print("Change Calculator")

cont='y'
while cont=='y' or cont=='Y':
    cents=int(input("\nEnter number of cents: "))
    
    q=cents//25
    d=(cents-q*25)//10
    n=(cents-d*10-q*25)//5
    p=cents-n*5-d*10-q*25
    
    print("\nQuarters: ", q)
    print("Dimes: ", d)
    print("Nickels: ", n)
    print("Pennies: ", p)

    cont=input("\nContinue? (y/n):")
print("\nBye!")
# Out:
# Change Calculator
#
# Enter number of cents: 99
#
# Quarters:  3
# Dimes:  2
# Nickels:  0
# Pennies:  4
#
# Continue? (y/n):y
#
# Enter number of cents: 55
#
# Quarters:  2
# Dimes:  0
# Nickels:  1
# Pennies:  0
#
# Continue? (y/n):n
#
# Bye!

# %% [markdown]
# ## 3.4 - Table of Powers
# Create a program that displays a table of squares and cubes for the specified range of numbers.
#
# ### Console
# ```powershell
# Table of Powers
#
# Start number: 90
# Stop number: 100
#
# Number	Squared	Cubed
# ======	=======	=====
# 90      8100	729000
# 91      8281	753571
# 92      8464	778688
# 93      8649	804357
# 94      8836	830584
# 95      9025	857375
# 96      9216	884736
# 97      9409	912673
# 98      9604	941192
# 99      9801	970299
# 100     10000	1000000
# ```
#
# ### Specifications
# - The formulas for calculating squares and cubes are:
#
#     `square = x ** 2`
#
#     `cube = x ** 3`
#
# - Use tabs to align the columns.
# - Assume that the user will enter valid integers.
# - Make sure the user enters a start integer that’s less than the stop integer. If the user enters a start integer that’s greater than the stop integer, display an error message and give the user a chance to enter the integers again.

# %%
print("Table of Powers\n")

start=int(input("Start number: "))
stop=int(input("Stop number: "))
while start>stop:
    print("INVALID!!! The start number must be lesser than the stop number. Try again!")
    start=int(input("Start number: "))
    stop=int(input("Stop number: "))
    
print("\nNumber\tSquared\tCubed")
print("======\t=======\t=====")
for i in range(start, stop+1):
    print(i, "\t", i**2, "\t", i**3)
# Out:
# Table of Powers
#
# Start number: 100
# Stop number: 90
# INVALID!!! The start number must be lesser than the stop number. Try again!
# Start number: 98
# Stop number: 2
# INVALID!!! The start number must be lesser than the stop number. Try again!
# Start number: 90
# Stop number: 100
#
# Number	Squared	Cubed
# ======	=======	=====
# 90 	 8100 	 729000
# 91 	 8281 	 753571
# 92 	 8464 	 778688
# 93 	 8649 	 804357
# 94 	 8836 	 830584
# 95 	 9025 	 857375
# 96 	 9216 	 884736
# 97 	 9409 	 912673
# 98 	 9604 	 941192
# 99 	 9801 	 970299
# 100 	 10000 	 1000000
